# %% [markdown]
# import pandas as pd

# %%
# !pip install openpyxl
import os
import pandas as pd

# Define the directory where your dataframes are stored
directory_path = 'datasets/companies'

# Initialize an empty dataframe to store the combined data
combined_df = pd.DataFrame()

# Loop through files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.xlsx'):  # Assuming your dataframes are in CSV files
        file_path = os.path.join(directory_path, filename)
        
        # Load each dataframe and concatenate it to the combined dataframe
        df = pd.read_excel(file_path)
        df["year"] = int(filename.split("_")[0])
        df.drop(df.index[-1], inplace=True)
        combined_df = pd.concat([combined_df, df], ignore_index=True)

# Now combined_df contains all the data from the dataframes in the directory
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.2 MB/s eta 0:00:0000:01
# ...

# %%
df
# Out:
#                         Company Name Company Nation  \
# 0                      JUUL Labs Inc  United States
# 1      Forest City Realty Trust, Inc  United States
# 2        Gramercy Property Trust Inc  United States
# 3               Wework Companies Inc  United States
# 4          Refinitiv US Holdings Inc  United States
# ...                              ...            ...
# 7435                   LA Collective  United States
# 7436  Breuer Premium Pet Food Co Inc  United States
# 7437                     Inovues Inc  United States
# 7438           Empire Auto Parts LLC  United States
# 7439        Superfly Productions LLC  United States
#
#      Investee Company TRBC Economic Sector No. of Deals in Search Range  \
# 0                       Consumer Cyclicals                            2
# 1                              Real Estate                            1
# 2                              Real Estate                            1
# ...

# %%
temp = combined_df.sort_values('year', ascending=False).drop_duplicates('Company Name')

# %%
temp
# Out:
#                                 Company Name Company Nation  \
# 58675                                    NaN            NaN
# 7355               Accutar Biotechnology Inc  United States
# 7359       United Land Services Holdings LLC  United States
# 7360        Arcus Financial Intelligence Inc  United States
# 7358   Southern Sports Medicine Partners LLC  United States
# ...                                      ...            ...
# 68611                             Tanvas Inc  United States
# 68608           United States Appraisals LLC  United States
# 68597                             Reelio Inc  United States
# 68600               Interleukin Genetics Inc  United States
# 68569                           Carelinx Inc  United States
#
#       Investee Company TRBC Economic Sector No. of Deals in Search Range  \
# 58675                           Industrials                          NaN
# 7355                             Healthcare                            1
# ...

# %%
combined_df["Company Name"].nunique()
# Out:
# 26234

# %%
combined_df[combined_df["Company Name"].str.contains('llc', na=False)==True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 combined_df[combined_df["Company Name"].str.contains('llc', na=False)==True]
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'Company Name'

# %%
temp.nunique()
# Out:
# Company Name                                               26234
# Company Nation                                                 1
# Investee Company TRBC Economic Sector                         13
# No. of Deals in Search Range                                  17
# No. of Firms in Search Range                                  22
# No. of Funds in Search Range                                  21
# Avg Deal Value in Search Range\n(USD, Millions)              699
# Avg Equity Per Deal in Search Range\n(USD, Millions)        2626
# Avg Equity Per Firm in Search Range\n(USD, Millions)        2221
# Avg Equity Per Fund in Search Range\n(USD, Millions)        2202
# Sum of Equity Invested in Search Range\n(USD, Millions)     2773
# Sum of Deal Value in Search Range\n(USD, Millions)           673
# Sum of Deal Rank Value in Search Range\n(USD, Millions)     3045
# Investee Primary SIC\n('|')                                  815
# ...

# %%
temp["Investee Company NAICS 2022\n('|')"].value_counts()[:20]
# Out:
# Investee Company NAICS 2022\n('|')
# Software Publishers                                                                       7516
# Web Search Portals and All Other Information Services                                     1700
# Research and Development in Biotechnology (except Nanobiotechnology)                      1215
# All Other Personal Services                                                                535
# Custom Computer Programming Services                                                       512
# Computing Infrastructure Providers, Data Processing, Web Hosting, and Related Services     452
# Lessors of Nonresidential Buildings (except Miniwarehouses)                                437
# Lessors of Residential Buildings and Dwellings                                             426
# Surgical and Medical Instrument Manufacturing                                              416
# ...

# %%
temp["Investee Primary SIC\n('|')"].value_counts()[:50]
# Out:
# Investee Primary SIC\n('|')
# Prepackaged Software                                  7750
# Information retrieval services                        1604
# Commercial physical and biological research           1199
# Computer programming services                          542
# Misc personal services                                 519
# Business services, nec                                 458
# Operators of nonresidential buildings                  434
# Surgical and medical instruments and apparatus         419
# Operators of apartment buildings                       413
# Data processing services                               406
# Pharmaceutical preparations                            354
# Management consulting services                         349
# Electromedical and electrotherapeutic apparatus        327
# Lessors of real property, nec                          319
# Catalog and mail-order houses                          229
# ...

# %%
temp["Investee SIC\n('|')"].value_counts()[:50]
# Out:
# Investee SIC\n('|')
# Prepackaged Software                                  7750
# Information retrieval services                        1604
# Commercial physical and biological research           1199
# Computer programming services                          542
# Misc personal services                                 519
# Business services, nec                                 458
# Operators of nonresidential buildings                  434
# Surgical and medical instruments and apparatus         419
# Operators of apartment buildings                       413
# Data processing services                               406
# Pharmaceutical preparations                            354
# Management consulting services                         349
# Electromedical and electrotherapeutic apparatus        327
# Lessors of real property, nec                          319
# Catalog and mail-order houses                          229
# Eating places                                          191
# ...

# %%
temp["Investee Company TRBC Activity\n('|')"].value_counts()[:50]
# Out:
# Investee Company TRBC Activity\n('|')
# Software (NEC)                                        4019
# Online Services (NEC)                                 1481
# Enterprise Software                                   1286
# Real Estate Rental, Development & Operations (NEC)    1155
# Application Software                                  1142
# Biotechnology & Medical Research (NEC)                 848
# IT Services & Consulting (NEC)                         828
# Personal Services (NEC)                                594
# Bio Therapeutic Drugs                                  492
# Business Support Services (NEC)                        461
# Mobile Application Software                            447
# Hospitals, Clinics & Primary Care Services             318
# Medical Software & Technology Services                 314
# Pharmaceuticals (NEC)                                  275
# Healthcare Facilities & Services (NEC)                 260
# ...

# %%
temp["Investee Company VE Primary Industry Sub-Group 3\n('|')"].value_counts()[:50]
# Out:
# Investee Company VE Primary Industry Sub-Group 3\n('|')
# Real Estate                                                                                          1362
# Business and Office Software                                                                         1311
# Medical/Health Software                                                                               796
# Expert Systems                                                                                        672
# Security/Firewalls, Encryption software                                                               600
# Consumer Products                                                                                     478
# Banks/Financial Institutions Software                                                                 427
# Finance/Insurance/Real Estate Services                                                                400
# ...

# %%
# !pip install openai

# %%
import openai
openai.api_key = "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"

response = openai.Completion.create(
    engine="text-davinci-002",  # Choose an appropriate engine
    prompt="Given a list of companies ['OpenAI','Meta']. Give 3 keywords for each company to describe which research areas each company falls under, as a python list of lists",
    max_tokens=50  # Set a limit on the length of the response
)

generated_text = response.choices[0].text

# %%
generated_text
# Out:
# ".\n\n[['Artificial intelligence', 'Machine learning', 'Deep learning'], ['Augmented reality', 'Virtual reality', 'Mixed reality']]"

# %%
list(temp["Company Name"])[:50]
# Out:
# [nan,
#  'Accutar Biotechnology Inc',
#  'United Land Services Holdings LLC',
#  'Arcus Financial Intelligence Inc',
#  'Southern Sports Medicine Partners LLC',
#  'Cru Inc',
#  'TapResearch Inc',
#  'Tillman Infrastructure LLC',
#  'Southwind Royalty Holdings',
#  'American Academy LLC',
#  'American Institute of Architects',
#  'Xcures Inc',
#  'Suggestic Inc',
#  'Vector Flow Inc',
#  'Foreside Financial Group LLC',
#  'Bluefin Payment Systems LLC',
#  'Neustar Inc',
#  'Expedia Group Inc',
#  'Folio Financial Inc',
#  'Surestaff LLC',
#  'Secure Natural Resources LLC',
#  'Belcan LLC',
#  'Newterra Corp Inc',
#  'Upper Echelon Products LLC',
#  'CAMBRIO',
#  'Temp-Con Inc',
#  'Powerschool Group LLC',
#  'Barrette Outdoor Living Inc',
#  'Despegar Com Inc',
#  'Bridgetower Media LLC',
#  'Vascular Dynamics Inc',
#  'Unison Therapy Services',
#  'ExteNet Systems Inc',
#  'Crowdsmart Inc',
#  'Netsmart Technologies Inc',
#  'Mediafly Inc',
#  'Syneo LLC',
# ...

# %%
list(js)
# Out:
# ['properties', 'cards']

# %%
js["properties"]
# Out:
# {'identifier': {'uuid': '1dcf3d60-e7a2-95f0-0fbb-0c7a307184c0',
#   'value': 'goBaby',
#   'image_id': 'v1485305805/htbednnsfgdbm8zhd0zp.png',
#   'permalink': 'gobaby-2',
#   'entity_def_id': 'organization'}}

# %%
list(js["cards"]["fields"])
# Out:
# ['company_type',
#  'location_group_identifiers',
#  'rank_delta_d30',
#  'founded_on',
#  'website',
#  'equity_funding_total',
#  'identifier',
#  'founder_identifiers',
#  'description',
#  'category_groups',
#  'linkedin',
#  'short_description',
#  'num_current_positions',
#  'operating_status',
#  'rank_org',
#  'facebook',
#  'num_employees_enum',
#  'status',
#  'funding_total',
#  'num_funding_rounds',
#  'last_equity_funding_type',
#  'last_funding_type',
#  'categories',
#  'created_at',
#  'location_identifiers',
#  'num_articles',
#  'last_funding_at',
#  'num_event_appearances',
#  'twitter',
#  'rank_delta_d90',
#  'updated_at',
#  'last_equity_funding_total',
#  'contact_email',
#  'funding_stage',
#  'rank_delta_d7',
#  'last_funding_total',
#  'num_founders']

# %%
z = pd.read_csv("datasets/organizations.csv", nrows=10000000)

# %%
z.shape
# Out:
# (2953634, 16)

# %%
z
# Out:
#                                          uuid                           name  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd                       Wetpaint
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                           Digg
# 3        f4d5ab44-058b-298b-ea81-380e6e9a8eec                Omidyar Network
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb                           Meta
# ...                                       ...                            ...
# 2953629  4464b840-604e-4664-9541-0ecc38b6fb71                     ASL Aspire
# 2953630  f2e19185-fe01-466a-a923-613d60a49e18  Royale Touche Vitrified Tiles
# 2953631  04d52dc7-8bc7-498d-8cac-cccbeeaabc6a              Festivus Festoons
# 2953632  c31112fc-7e8e-42b0-a4f1-661a66c429b7                   Ramazan Uzal
# 2953633  30c0f2d3-cc3d-4457-8846-5b3d751baba6                        Purever
#
#                  type primary_role  \
# ...

# %%
z[z["name"].str.contains('Myfitnesspal llc', na=False, case=False)==True]
# Out:
# Empty DataFrame
# Columns: [uuid, name, type, primary_role, cb_url, domain, homepage_url, logo_url, facebook_url, twitter_url, linkedin_url, combined_stock_symbols, city, region, country_code, short_description]
# Index: []

# %%
z[z["uuid"]=="626e5d3c-46bd-b265-c168-183c2a33094b"]
# Out:
#                                        uuid          name          type  \
# 21464  626e5d3c-46bd-b265-c168-183c2a33094b  MyFitnessPal  organization
#
#       primary_role                                             cb_url  \
# 21464      company  https://www.crunchbase.com/organization/myfitn...
#
#                  domain                   homepage_url  \
# 21464  myfitnesspal.com  https://www.myfitnesspal.com/
#
#                                                 logo_url  \
# 21464  https://images.crunchbase.com/image/upload/t_c...
#
#                                  facebook_url  \
# 21464  https://www.facebook.com/myfitnesspal/
#
#                             twitter_url  \
# 21464  https://twitter.com/MyFitnessPal
#
#                                         linkedin_url combined_stock_symbols  \
# 21464  https://www.linkedin.com/company/myfitnesspal                    NaN
#
#                 city      region country_code  \
# 21464  San Francisco  California          USA
#
# ...

# %%
# !pip install fuzzywuzzy

import fuzzywuzzy

# Find the closest match for the name "John Doe"
closest_match = process.extractOne('Myfitnesspal llc', z['name'])

# Print the closest match
print(closest_match)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 6
#       3 import fuzzywuzzy
#       5 # Find the closest match for the name "John Doe"
# ----> 6 closest_match = process.extractOne('Myfitnesspal llc', z['name'])
#       8 # Print the closest match
#       9 print(closest_match)
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/fuzzywuzzy/process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/fuzzywuzzy/process.py:110, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     108 for key, choice in choices.items():
# ...

# %%
from fuzzywuzzy import process
# Out:
# /Users/parthmaheshwari/miniconda3/envs/cse890/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
import requests

response = requests.get('https://api.crunchbase.com/api/v4/autocompletes?query=Comparably&collection_ids=organizations',headers={"X-cb-user-key":"453a4afa520c60eb1a9edc588c78f26b","accept": "application/json"})

# %%
import json
json.loads(response.text)["entities"][0]
# Out:
# {'facet_ids': ['contact',
#   'siftery',
#   'ipqwery',
#   'privco',
#   'aberdeen',
#   'semrush',
#   'company',
#   'rank',
#   'builtwith',
#   'bombora'],
#  'identifier': {'uuid': 'fdcba4bf-b546-6229-e3b3-18f8772a665c',
#   'value': 'Comparably',
#   'image_id': 'v1459359335/vpkgsmmo8nobm0olbxqv.jpg',
#   'permalink': 'comparably',
#   'entity_def_id': 'organization'},
#  'short_description': 'Comparably, a platform that provides culture & compensation data for public and private companies.'}

# %%
website = requests.get("https://www.myfitnesspal.com/")

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.myfitnesspal.com/"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# Calorie Tracker & BMR Calculator to Reach Your Goals | MyFitnessPalReviewsHow It WorksAppsOur Philosophy#1 nutrition tracking appReach your goals with MyFitnessPalBuild healthy habits with the all-in-one food, exercise, and calorie tracker.Start Today3.7 Million 5-Star Reviews“Helped me get moving on my goals and tracking my weight loss and bodybuilding.”Jason L.“Good for tracking calories and macros with a huge database of food.”Iain M.“Friendly, easy-to-use app that keeps me accountable.”Dinah L.“Can’t lose weight and stay on track without it.”Jennie S.“Love this app. It keeps me on track with my nutritional goals.”Annette B.Hit your health goals in 1-2-31Track food, fitness & fastingTracking calories and macros is easy with our barcode scanner and device integration.2Learn what worksPersonalized nutrition insights reveal what's working so you can make smarter choices.3Change your habits and reach your goalsNow you have the tools and knowledge to build healthy habits for life.35+ a
# ...

# %%
# !pip install textblob
from textblob import TextBlob
txt = """Natural language processing (NLP) is a field of computer science, artificial intelligence, and computational linguistics concerned with the interactions between computers and human (natural) languages."""
blob = TextBlob(txt)
print(blob.noun_phrases)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 9.3 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.1 MB/s eta 0:00:0000:01
# ...
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/2c/74/ea77ab33736614442585bf8944feb95ffcf1cb9e8ef580aada6f1e5ba73a/regex-2023.10.3-cp38-cp38-macosx_11_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 28.2 MB/s eta 0:00:00
# ...

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import RegexpParser
from nltk import Tree
import pandas as pd

def get_continuous_chunks(text, chunk_func=ne_chunk):
    chunked = chunk_func(pos_tag(word_tokenize(text)))
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

z['short_description'][:50].apply(lambda sent: get_continuous_chunks((sent)))
# Out:
# 0                            [Wetpaint]
# 1                                [Zoho]
# 2                           [Digg Inc.]
# 3                     [Omidyar Network]
# 4                                [Meta]
# 5                    [Trinity Ventures]
# 6                               [Accel]
# 7                    [Meritech Capital]
# 8                           [Omnidrive]
# 9                                [Geni]
# 10                            [Flektor]
# 11              [Fox Interactive Media]
# 12                                  [X]
# 13                        [StumbleUpon]
# 14                             [Gizmoz]
# 15                             [Scribd]
# 16                            [Slacker]
# 17                           [Ventures]
# 18                   [Mission Ventures]
# 19                                   []
# 20                             [Austin]
# 21                           [Redpoint]
# 22                               [Lala]
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parthmaheshwari/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/parthmaheshwari/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/parthmaheshwari/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/parthmaheshwari/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
temp["Investee Company VE Primary Industry Sub-Group 3\n('|')"][:100].apply(lambda sent: get_continuous_chunks((sent)))
# Out:
# 58675            []
# 7355             []
# 7359             []
# 7360             []
# 7358             []
#             ...
# 7409             []
# 7379             []
# 7393             []
# 7380     [Database]
# 7381             []
# Name: Investee Company VE Primary Industry Sub-Group 3\n('|'), Length: 100, dtype: object

# %% [markdown]
# # Bertopic

# %%
# !pip install bertopic
# Out:
# ...
#   Obtaining dependency information for bertopic from https://files.pythonhosted.org/packages/06/49/f395e2e4d21dd49803494c8aec6087db61ea0ba211c6e5e57540b23334eb/bertopic-0.15.0-py2.py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 19.0 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 330.7 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for scikit-learn>=0.22.2.post1 from https://files.pythonhosted.org/packages/3b/8e/510fca8967185df0099c006663702c0c17a4c58f6d3b6eb86c20426141c0/scikit_learn-1.3.1-cp38-cp38-macosx_12_0_arm64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.0 MB/s eta 0:00:00ta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...

# %%
from bertopic import BERTopic

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(list(z["short_description"])[:10000])

# %%
from sklearn.datasets import fetch_20newsgroups
 
docs = fetch_20newsgroups(subset='test',  remove=('headers', 'footers', 'quotes'))['data']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 3
#       1 from sklearn.datasets import fetch_20newsgroups
# ----> 3 docs = fetch_20newsgroups(subset='test',  remove=('headers', 'footers', 'quotes'))['data']
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
# ...

# %%
list(z["short_description"])
# Out:
# ['Wetpaint offers an online social publishing platform that helps digital publishers grow their customer base.',
#  'Zoho offers a suite of business, collaboration, and productivity applications.',
#  'Digg Inc. operates a website that enables its users to find, read, and share the most interesting and talked about stories on the internet.',
#  'Omidyar Network is an investment firm.',
#  'Meta is a social technology company that enables people to connect, find communities, and grow businesses.',
#  'Trinity Ventures is an early stage venture capital firm.',
#  'Accel is an seed and growth-stage venture capital firm that helps a global community of entrepreneurs.',
#  'Meritech Capital provides late-stage venture capital to technology companies.',
#  'Omnidrive provides online storage facilities that allow users to access, edit and share their files via a web browser.',
#  'Geni is an online community of genealogists collaborating to help individuals build their own family trees.',
# ...

# %%
topic_model.get_topic_info().head(50)
# Out:
#     Topic  Count                                        Name  \
# 0      -1   3840                         -1_and_mobile_is_to
# 1       0    753             0_capital_venture_firm_ventures
# 2       1    287                 1_music_radio_artists_audio
# 3       2    197       2_media_digital_entertainment_company
# 4       3    158             3_games_game_gaming_multiplayer
# 5       4    156            4_design_web_development_company
# 6       5    148            5_advertising_ad_advertisers_ads
# 7       6    138            6_marketing_digital_agency_brand
# 8       7    136       7_students_learning_college_education
# 9       8    124                 8_photo_photos_image_images
# 10      9    118                 9_job_talent_jobs_employers
# 11     10    107           10_health_medical_care_healthcare
# 12     11    106       11_social_network_networking_networks
# 13     12     89                12_sports_fantasy_sport_fans
# ...

# %%
# Out:
#                                          uuid                           name  \
# 0        e1393508-30ea-8a36-3f96-dd3226033abd                       Wetpaint
# 1        bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7                           Zoho
# 2        5f2b40b8-d1b3-d323-d81a-b7a8e89553d0                           Digg
# 3        f4d5ab44-058b-298b-ea81-380e6e9a8eec                Omidyar Network
# 4        df662812-7f97-0b43-9d3e-12f64f504fbb                           Meta
# ...                                       ...                            ...
# 2953629  4464b840-604e-4664-9541-0ecc38b6fb71                     ASL Aspire
# 2953630  f2e19185-fe01-466a-a923-613d60a49e18  Royale Touche Vitrified Tiles
# 2953631  04d52dc7-8bc7-498d-8cac-cccbeeaabc6a              Festivus Festoons
# 2953632  c31112fc-7e8e-42b0-a4f1-661a66c429b7                   Ramazan Uzal
# 2953633  30c0f2d3-cc3d-4457-8846-5b3d751baba6                        Purever
#
#                  type primary_role  \
# ...

# %% [markdown]
# # Joining CB and Refinitiv

# %%
temp.drop(temp.index[0], inplace=True)

# %%
temp
# Out:
#                                 Company Name Company Nation  \
# 7355               Accutar Biotechnology Inc  United States
# 7359       United Land Services Holdings LLC  United States
# 7360        Arcus Financial Intelligence Inc  United States
# 7358   Southern Sports Medicine Partners LLC  United States
# 7357                                 Cru Inc  United States
# ...                                      ...            ...
# 68611                             Tanvas Inc  United States
# 68608           United States Appraisals LLC  United States
# 68597                             Reelio Inc  United States
# 68600               Interleukin Genetics Inc  United States
# 68569                           Carelinx Inc  United States
#
#       Investee Company TRBC Economic Sector No. of Deals in Search Range  \
# 7355                             Healthcare                            1
# 7359                            Industrials                            6
# ...

# %%
sample_companies = temp.sample(1000)

# %%
sample_companies
# Out:
#                           Company Name Company Nation  \
# 129120  Jordan Healthcare Holdings Inc  United States
# 116006                    Device42 Inc  United States
# 3238                      Truthset Inc  United States
# 18386                  Quentin Corners  United States
# 70673                         Elli Inc  United States
# ...                                ...            ...
# 129970             EZShield Parent Inc  United States
# 51678                        Vkidz Inc  United States
# 51609          Pathfinder Aviation LLC  United States
# 14248                   Captricity Inc  United States
# 68673                      Emmerge Inc  United States
#
#        Investee Company TRBC Economic Sector No. of Deals in Search Range  \
# 129120                            Healthcare                            2
# 116006                            Technology                            1
# 3238                              Technology                            1
# ...

# %%
import requests

def get_short_description(company_name):
    try:
        response = requests.get(f'https://api.crunchbase.com/api/v4/autocompletes?query={company_name}&collection_ids=organizations',headers={"X-cb-user-key":"453a4afa520c60eb1a9edc588c78f26b","accept": "application/json"})
        sd = json.loads(response.text)["entities"][0]["short_description"]
        print(company_name + " Success")
    except Exception as e:
        print(company_name + " Fail")
        sd = None
    return sd

sample_companies["short_description"] = sample_companies["Company Name"].apply(get_short_description)
# Out:
# Jordan Healthcare Holdings Inc Success
# Device42 Inc Success
# Truthset Inc Success
# Quentin Corners Success
# Elli Inc Success
# Cardeeo Inc Success
# Grubbly Farms Inc Success
# Core Institute, The Success
# Bind Benefits Inc Success
# Sevence LLC Success
# Sterling Pointe Success
# Cforia Software LLC Success
# PeraHealth Inc Success
# Wing Tel Inc Success
# Everywhere Communications Inc Success
# WMK LLC Success
# Trifo Inc Success
# Skycatch Inc Success
# Wrap Media LLC Success
# Foundry Point Apartments Success
# SEI INC Success
# Girard Environmental Services LLC Success
# Narrative I/O Inc Success
# Veritas Permian II LLC Success
# Nylas Inc Success
# Tienda Pago Management LLC Success
# Excel Sports Management LLC Success
# WhisperAi Inc Success
# Torch 3D Inc Success
# Panty Prop Inc Success
# eco2Dye Success
# Medicinal Genomics Corp Success
# PDS Biotechnology Corp Success
# Cyren Ltd Success
# OTG Experience LLC Success
# Freehand Hotels Success
# ...

# %%
sample_companies["Company Name"]
# Out:
# 129120    Jordan Healthcare Holdings Inc
# 116006                      Device42 Inc
# 3238                        Truthset Inc
# 18386                    Quentin Corners
# 70673                           Elli Inc
#                        ...
# 129970               EZShield Parent Inc
# 51678                          Vkidz Inc
# 51609            Pathfinder Aviation LLC
# 14248                     Captricity Inc
# 68673                        Emmerge Inc
# Name: Company Name, Length: 1000, dtype: object

# %%
from collections import Counter
results = Counter()
temp['Company Name'].str.lower().str.split().apply(results.update)
print(results)
# Out:
# Counter({'inc': 15613, 'llc': 5568, 'corp': 1083, 'technologies': 834, 'group': 664, 'holdings': 617, 'solutions': 540, 'health': 511, 'services': 443, 'therapeutics': 433, 'systems': 417, '&': 384, 'co': 383, '-': 378, 'labs': 339, 'medical': 329, 'partners': 320, 'inc.': 307, 'ltd': 264, 'energy': 250, 'software': 229, 'technology': 224, 'the': 215, 'international': 198, 'management': 195, 'capital': 193, 'company': 185, 'media': 174, 'products': 167, 'center': 151, 'global': 144, 'financial': 142, 'lp': 142, 'and': 141, 'pharmaceuticals': 141, 'networks': 133, 'data': 132, 'portfolio': 128, 'apartments': 127, 'industries': 125, 'at': 120, 'brands': 117, 'biosciences': 117, 'industrial': 116, 'foods': 114, 'of': 109, 'network': 103, 'healthcare': 99, 'care': 97, 'power': 95, 'security': 95, 'us': 93, 'business': 93, 'insurance': 85, 'enterprises': 85, 'analytics': 85, 'american': 82, 'holding': 80, 'park': 79, 'resources': 77, 'bio': 77, 'digital': 77, 'usa': 77, 'ai': 77, 'buildin
# ...

# %%
len(df)
# Out:
# 7440

# %%
sample_companies['Company Name'].str.lower().str.split().replace('inc|llc|group|holdings|co|inc.|holding|partners|ltd', '')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[145], line 1
# ----> 1 sample_companies['Company Name'].str.lower().str.split().replace('inc|llc|group|holdings|co|inc.|holding|partners|ltd', '').strip()
#
# File ~/miniconda3/envs/cse890/lib/python3.8/site-packages/pandas/core/generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
comp_suffixes = ["inc","llc","group","holdings","co","inc.","holding","partners","ltd"]
sample_companies['Company Name'].str.lower().replace('|'.join(comp_suffixes), '', regex=True).str.strip()
# Out:
# 129120      jordan healthcare
# 116006               device42
# 3238                 truthset
# 18386           quentin rners
# 70673                    elli
#                  ...
# 129970        ezshield parent
# 51678                   vkidz
# 51609     pathfinder aviation
# 14248              captricity
# 68673                 emmerge
# Name: Company Name, Length: 1000, dtype: object

# %%
sample_companies
# Out:
#                           Company Name Company Nation  \
# 129120  Jordan Healthcare Holdings Inc  United States
# 116006                    Device42 Inc  United States
# 3238                      Truthset Inc  United States
# 18386                  Quentin Corners  United States
# 70673                         Elli Inc  United States
# ...                                ...            ...
# 129970             EZShield Parent Inc  United States
# 51678                        Vkidz Inc  United States
# 51609          Pathfinder Aviation LLC  United States
# 14248                   Captricity Inc  United States
# 68673                      Emmerge Inc  United States
#
#        Investee Company TRBC Economic Sector No. of Deals in Search Range  \
# 129120                            Healthcare                            2
# 116006                            Technology                            1
# 3238                              Technology                            1
# ...
